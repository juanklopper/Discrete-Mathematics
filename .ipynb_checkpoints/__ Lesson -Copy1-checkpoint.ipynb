# %%
import sympy as sym

# %%
sym.init_printing(use_latex = "mathjax")

# %% [markdown]
# #

# %% [markdown]
# ## In this lesson

# %% [markdown]
# Follow these links
# - [Introduction](#Introduction)
# - [](#)
# - [](#)
# - [](#)
# - [](#)
# - [](#)
# - [](#)
# - [](#)
# - [](#)
# - [](#)
# - [](#)
# - [](#)

# %% [markdown]
# ## Introduction

# %% [markdown]
# [Back to the top](#In-this-lesson)
